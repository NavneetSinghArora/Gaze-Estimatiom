# %%
# Mounting Google Drive

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd ./drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# Cloning the Few Shot Gaze Repository

# !git clone https://github.com/NVlabs/few_shot_gaze.git
# Out:
# fatal: destination path 'few_shot_gaze' already exists and is not an empty directory.

# %%
# Changing directory to the Project Folder

# %cd few_shot_gaze/
# Out:
# /content/drive/MyDrive/few_shot_gaze

# %%
pwd
# Out:
# '/content/drive/MyDrive/few_shot_gaze'

# %%
# Adding required submodules

# !git submodule update --init --recursive
# Out:
# Submodule 'demo/ext/HRNet-Facial-Landmark-Detection' (https://github.com/HRNet/HRNet-Facial-Landmark-Detection) registered for path 'demo/ext/HRNet-Facial-Landmark-Detection'
# Submodule 'demo/ext/eos' (https://github.com/patrikhuber/eos) registered for path 'demo/ext/eos'
# Submodule 'preprocess' (https://github.com/swook/faze_preprocess) registered for path 'preprocess'
# Cloning into '/content/drive/My Drive/few_shot_gaze/demo/ext/HRNet-Facial-Landmark-Detection'...
# Cloning into '/content/drive/My Drive/few_shot_gaze/demo/ext/eos'...
# Cloning into '/content/drive/My Drive/few_shot_gaze/preprocess'...
# Submodule path 'demo/ext/HRNet-Facial-Landmark-Detection': checked out 'acdec19ebb631d0116574f85b367de075ef789f3'
# Submodule path 'demo/ext/eos': checked out '9ac31018893bc1f3adda7382725c383e1560cfac'
# Submodule '3rdparty/cereal' (https://github.com/USCiLab/cereal.git) registered for path 'demo/ext/eos/3rdparty/cereal'
# ...

# %%
# Installing required libraries

# !pip3 install --user --upgrade -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 4.0MB 12.0MB/s
# ...
#      |████████████████████████████████| 3.3MB 48.0MB/s
# ...
#      |████████████████████████████████| 389kB 56.9MB/s
# Requirement already up-to-date: numpy in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (1.19.5)
# ...
#      |████████████████████████████████| 50.4MB 56kB/s
# ...
#      |████████████████████████████████| 776.8MB 24kB/s
# ...
#      |████████████████████████████████| 12.8MB 245kB/s
# ...
#      |████████████████████████████████| 81kB 10.6MB/s
# ...
#      |████████████████████████████████| 317kB 55.0MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 716kB 47.0MB/s
# ...
#      |████████████████████████████████| 327kB 54.6MB/s
# ...
#      |████████████████████████████████| 174kB 55.9MB/s
# ...
#      |████████████████████████████████| 26.9MB 111kB/s
# ...
#      |████████████████████████████████| 245kB 59.4MB/s
# ...

# %%
# %cd src/
# Out:
# /content/drive/My Drive/few_shot_gaze/src

# %%
# !wget -N https://ait.ethz.ch/projects/2019/faze/downloads/outputs_of_full_train_test_and_plot.zip
# Out:
# --2020-12-22 17:17:37--  https://ait.ethz.ch/projects/2019/faze/downloads/outputs_of_full_train_test_and_plot.zip
# Resolving ait.ethz.ch (ait.ethz.ch)... 129.132.85.38
# Connecting to ait.ethz.ch (ait.ethz.ch)|129.132.85.38|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1250559857 (1.2G) [application/zip]
# Saving to: ‘outputs_of_full_train_test_and_plot.zip’
#
# outputs_of_full_tra 100%[===================>]   1.16G  19.0MB/s    in 66s
#
# 2020-12-22 17:18:44 (18.1 MB/s) - ‘outputs_of_full_train_test_and_plot.zip’ saved [1250559857/1250559857]

# %%
# !unzip -o outputs.zip
# Out:
# Archive:  outputs.zip
#    creating: outputs/
#   inflating: outputs/MPIIGaze.h5

# %%
pwd
# Out:
# '/content/drive/My Drive/few_shot_gaze/preprocess'

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 17691146973270330903, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15692777408
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 862628461615243137
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
# !nvidia-smi
# Out:
# Sat Jan 16 18:09:59 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    32W / 250W |    359MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install torch==1.6.0+cu101 torchvision==0.7.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 708.0MB 26kB/s
# ...
#      |████████████████████████████████| 5.9MB 27.0MB/s
# ...
#   Found existing installation: torch 1.7.1
#     Uninstalling torch-1.7.1:
#       Successfully uninstalled torch-1.7.1
#   Found existing installation: torchvision 0.8.2
#     Uninstalling torchvision-0.8.2:
#       Successfully uninstalled torchvision-0.8.2
# ...

# %%
# %cd preprocess/
# Out:
# [Errno 2] No such file or directory: 'preprocess/'
# /content/drive/My Drive/few_shot_gaze/src

# %%
pwd
# Out:
# '/content/drive/My Drive/few_shot_gaze/preprocess'

# %%
# !unzip -o MPIIFaceGaze.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: MPIIFaceGaze/p00/day08/0565.jpg
#   inflating: __MACOSX/MPIIFaceGaze/p00/day08/._0565.jpg
#   inflating: MPIIFaceGaze/p00/day08/0639.jpg
#   inflating: __MACOSX/MPIIFaceGaze/p00/day08/._0639.jpg
#   inflating: MPIIFaceGaze/p00/day08/0163.jpg
#   inflating: __MACOSX/MPIIFaceGaze/p00/day08/._0163.jpg
#   inflating: MPIIFaceGaze/p00/day08/0177.jpg
#   inflating: __MACOSX/MPIIFaceGaze/p00/day08/._0177.jpg
#   inflating: MPIIFaceGaze/p00/day08/0374.jpg
#   inflating: __MACOSX/MPIIFaceGaze/p00/day08/._0374.jpg
#   inflating: MPIIFaceGaze/p00/day08/0557.jpg
#   inflating: __MACOSX/MPIIFaceGaze/p00/day08/._0557.jpg
#   inflating: MPIIFaceGaze/p00/day08/0742.jpg
#   inflating: __MACOSX/MPIIFaceGaze/p00/day08/._0742.jpg
#   inflating: MPIIFaceGaze/p00/day08/0030.jpg
#   inflating: __MACOSX/MPIIFaceGaze/p00/day08/._0030.jpg
#   inflating: MPIIFaceGaze/p00/day08/0186.jpg
#   inflating: __MACOSX/MPIIFaceGaze/p00/day08/._0186.jpg
# ...

# %%
# !bash grab_prerequisites.bash
# Out:
# ...
# --2021-01-16 14:09:40--  https://ait.ethz.ch/projects/2019/faze/downloads/preprocessing/MPIIFaceGaze_supplementary.h5
# Resolving ait.ethz.ch (ait.ethz.ch)... 129.132.85.38
# Connecting to ait.ethz.ch (ait.ethz.ch)|129.132.85.38|:443... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘MPIIFaceGaze_supplementary.h5’ not modified on server. Omitting download.
#
# --2021-01-16 14:09:41--  https://ait.ethz.ch/projects/2019/faze/downloads/preprocessing/GazeCapture_supplementary.h5
# Resolving ait.ethz.ch (ait.ethz.ch)... 129.132.85.38
# Connecting to ait.ethz.ch (ait.ethz.ch)|129.132.85.38|:443... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘GazeCapture_supplementary.h5’ not modified on server. Omitting download.

# %%
# !python3 create_hdf_files_for_faze.py
# Out:
# Processing MPIIGaze/p00
# Distortion map parameters updated.
# fx: 994.74, fy: 998.17, cx: 624.66, cy: 364.09
# qt.qpa.xcb: could not connect to display
# qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "/root/.local/lib/python3.6/site-packages/cv2/qt/plugins" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: xcb.

# %%
# %cd ../src
# Out:
# /content/drive/My Drive/few_shot_gaze/src

# %%
# !bash full_train_test_and_plot.bash
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2021-01-27 18:32:08,247 DTED(
#   (encoder): DenseNetEncoder(
#     (initial): DenseNetInitialLayers(
#       (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (norm): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (act): LeakyReLU(negative_slope=0.01, inplace=True)
#       (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     )
#     (block1): DenseNetBlock(
#       (compo1): DenseNetCompositeLayer(
#         (norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
# ...
